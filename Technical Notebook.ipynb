# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import Functions

# %%
import hypothesis_tests as ht
import data_cleaning
from visualizations import plot_distribution, visualization_four

# %% [markdown]
# # Import Data

# %%
cleaned_data = data_cleaning.full_clean()

# %% [markdown]
# # Preliminary Analysis

# %% [markdown]
# ## Total Hospital Charges

# %%
ht.hypothesis_test_one(cleaned_data,alpha = 0.05)
# Out:
# Based on the p value of 0.0 and our aplha of 0.05           we reject the null hypothesis.
#  Due to these results, we  can state that there           is a difference in charges between Hospitals in Metro and          Non-Metro Areas
# with an effect size, cohen's d, of 0.4389810421260751 and               power of 1.0.
# 'Reject'

# %% [markdown]
# __Distribution Plot__

# %%
metro_sample,non_metro_sample = ht.create_sample_dists(cleaned_data, y_var='average_covered_charges')

# %%
plot_distribution(metro_sample,'metro',non_metro_sample,'non_metro','Average Hospital Charges')

# %% [markdown]
# __Distribution of Means__

# %%
metro_means = ht.get_sample_means(metro_sample,100)
non_metro_means = ht.get_sample_means(non_metro_sample,100)

# %%
plot_distribution(metro_means,'metro',non_metro_means,'non_metro','Average Hospital Charges')

# %% [markdown]
# ## Out of Pocket

# %%
ht.hypothesis_test_two(cleaned_data,alpha = .05)
# Out:
# Based on the p value of 0.0 and our aplha of 0.05 we          reject the null hypothesis.
#  Due to these results, we  can state that           there is a difference in out-of-pocket cost for patients           using Hospitals in Metro vs. Non-Metro Areas
# with an effect size, cohen's d, of 0.30636307860576273 and              power of 1.0.
# 'Reject'

# %% [markdown]
# __Distribution Plots__

# %%
metro_sample,non_metro_sample = ht.create_sample_dists(
    cleaned_data, y_var='out_of_pocket')

# %%
plot_distribution(metro_sample,'metro',non_metro_sample,'non_metro','Out of Pocket')

# %% [markdown]
# __Distribution of Means__

# %%
metro_means = ht.get_sample_means(metro_sample,100)
non_metro_means = ht.get_sample_means(non_metro_sample,100)

# %%
plot_distribution(metro_means,'metro',non_metro_means,'non_metro','Out of Pocket')

# %% [markdown]
# ## % Charges Paid for Treatment

# %%
 ht.hypothesis_test_three(cleaned_data,alpha = .05)
# Out:
# Based on the p value of 0.0 and our aplha of 0.05 we          reject  the null hypothesis.
#  Due to these results, we  can state that there is           a difference in the percentage of charges covered by medicare for           Hospitals in Metro vs. Non-Metro Areas for the provided services.
# with an effect size, cohen's d, of 0.4110139499849583 and power               of 1.0.
# 'Reject'

# %% [markdown]
# __Distribution Plot__

# %%
metro_sample,non_metro_sample = ht.create_sample_dists(
    cleaned_data, y_var='perc_covered')

# %%
plot_distribution(metro_sample,'metro',non_metro_sample,'non_metro','% Charges Paid for Treatment')

# %% [markdown]
# __Distribution of Means__

# %%
metro_means = ht.get_sample_means(metro_sample,100)
non_metro_means = ht.get_sample_means(non_metro_sample,100)

# %%
plot_distribution(metro_means,'metro',non_metro_means,'non_metro','% Charges Paid for Treatment')

# %% [markdown]
# ## Diagnosis-Specific Hypothesis Tests

# %%
ht.hypothesis_test_four(cleaned_data)
# Out:
# HBox(children=(IntProgress(value=0, max=573), HTML(value='')))
# /home/peter/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3367: RuntimeWarning: Degrees of freedom <= 0 for slice
#   **kwargs)
# /home/peter/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#                                           Description  num_sig_procs  \
# 0   MDC 01: DISEASES & DISORDERS OF THE NERVOUS SY...             20
# 1   MDC 03: DISEASES & DISORDERS OF THE EAR, NOSE,...              1
# 2   MDC 04: DISEASES & DISORDERS OF THE RESPIRATOR...             23
# 3   MDC 05: DISEASES & DISORDERS OF THE CIRCULATOR...             48
# 4   MDC 06: DISEASES & DISORDERS OF THE DIGESTIVE ...             20
# 5   MDC 07: DISEASES & DISORDERS OF THE HEPATOBILI...             11
# 6   MDC 08: DISEASES & DISORDERS OF THE MUSCULOSKE...             23
# 7   MDC 09: DISEASES & DISORDERS OF THE SKIN, SUBC...              3
# 8   MDC 10: ENDOCRINE, NUTRITIONAL & METABOLIC DIS...              8
# 9   MDC 11: DISEASES & DISORDERS OF THE KIDNEY & U...             11
# 10  MDC 16: DISEASES & DISORDERS OF BLOOD, BLOOD F...              3
# 11  MDC 18: INFECTIOUS & PARASITIC DISEASES, SYSTE...              6
# 12                MDC 19: MENTAL DISEASES & DISORDERS              5
# 13  MDC 20: ALCOHOL/DRUG USE & ALCOHOL/DRUG INDUCE...              3
# 14  MDC 21: INJURIES, POISONINGS & TOXIC EFFECTS O...              3
# 15  MDC 23: FACTORS INFLUENCING HLTH STAT & OTHR C...              1
# 16                UNRELATED OPERATING ROOM PROCEDURES              3
#
#     sum_effect  Code_Start  Code_End  group_size  avg_effect    code
# 0    12.211395          20       103          83    0.147125  MDC 01
# 1     0.491407         129       159          30    0.016380  MDC 03
# 2    15.441093         163       208          45    0.343135  MDC 04
# 3    29.602112         215       316         101    0.293090  MDC 05
# 4    11.992597         326       395          69    0.173806  MDC 06
# 5     5.854254         405       446          41    0.142787  MDC 07
# 6    13.002090         453       566         113    0.115063  MDC 08
# 7     1.937029         570       607          37    0.052352  MDC 09
# 8     4.607626         614       645          31    0.148633  MDC 10
# 9     7.192570         652       700          48    0.149845  MDC 11
# 10    1.967921         799       816          17    0.115760  MDC 16
# 11    3.946533         853       872          19    0.207712  MDC 18
# 12    3.566688         876       887          11    0.324244  MDC 19
# 13    1.828290         894       897           3    0.609430  MDC 20
# 14    1.580056         901       923          22    0.071821  MDC 21
# 15    0.502148         939       951          12    0.041846  MDC 23
# 16    1.733612         981       989           8    0.216701  UNRELA

# %%
visualization_four(cleaned_data)
# Out:
# HBox(children=(IntProgress(value=0, max=573), HTML(value='')))
