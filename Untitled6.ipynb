# %%
import data_collection

# %%
data_collection.get_dirty_data()
# Out:
# Enter Google Maps API Key: AIzaSyBP2xr2XP2cMgMLlcrQJBw3o0f8R6lLCbE
#        average_covered_charges average_medicare_payments  \
# 0                   1126268.58                 182770.86
# 1                   1050063.13                 252782.53
# 2                    569379.33                 199879.20
# 3                   1058968.75                 189331.79
# 4                    802446.90                 188267.90
# 5                    570772.67                 199397.95
# 6                    777330.14                 175385.33
# 7                   1113213.79                 245171.84
# 8                    873338.40                 209552.57
# 9                    619413.33                 217176.33
# 10                   684593.83                 185513.50
# 11                   732092.39                 171274.25
# 12                   712240.27                 215098.00
# 13                   713919.82                 175311.94
# ...

# %%
import pandas as pd

# %%
data = pd.read_csv('./data/dirty_data', dtype=str)

# %%
data.head()
# Out:
#   Unnamed: 0 average_covered_charges average_medicare_payments  \
# 0          0              1126268.58                 182770.86
# 1          1              1050063.13                 252782.53
# 2          2               569379.33                 199879.20
# 3          3              1058968.75                 189331.79
# 4          4               802446.90                 188267.90
#
#   average_total_payments                                     drg_definition  \
# 0              189464.00  001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 1              301640.47  001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 2              211545.13  001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 3              198471.08  001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 4              321528.10  001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
#
#   hospital_referral_region_hrr_description provider_city provider_id  \
# ...

# %%
data['CSI'].value_counts()
# Out:
# 1    173301
# 2     20020
# 3      3843
# Name: CSI, dtype: int64

# %%
len(data.full_address.unique())
# Out:
# 3208

# %%
len(data.loc[data['CSI'] == '1'])
# Out:
# 173301

# %%
len(data.loc[data['CSI'] != '1'])
# Out:
# 23982

# %%
23982/173301
# Out:
# 0.13838350615403258
